# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nashville_growth_df = pd.read_csv('../data/building_permits_issued.csv')

# %%
nashville_growth_df
# Out:
#           Permit #       Permit Type Description  \
# 0       2018034633    Building Residential - New
# 1       2018074894     Building Commercial - New
# 2       2019015332     Building Commercial - New
# 3       2019052492      Building Use & Occupancy
# 4       2019058786      Building Use & Occupancy
# ...            ...                           ...
# 32201   2024087813          Building Sign Permit
# 32202  T2022070823    Building Residential - New
# 32203  T2023042807  Building Residential - Rehab
# 32204  T2023042806  Building Residential - Rehab
# 32205  T2024002604    Building Residential - New
#
#                      Permit Subtype Description          Parcel  \
# 0      Accessory Structure, Pools - Residential     16800024100
# 1      Self Service Storage, Storage Mod Hazard     17500008500
# 2      Multifamily, Apt / Twnhome > 5 Unit Bldg     10404017300
# 3       Multifamily, Tri-Plex, Quad, Apartments     09207033900
# ...
